# %%
import numpy as np
from IPython.core.pylabtools import figsize
figsize(10, 7)
import matplotlib.pyplot as plt

# Plot multiple systems together
file1= np.genfromtxt('64x64x64_dielectric_only.dat', delimiter = ' ')
file2= np.genfromtxt('64x64x64_dielectric+DFT.dat', delimiter = ' ')

import numpy as np
from IPython.core.pylabtools import figsize
figsize(10, 7)
import matplotlib.pyplot as plt

# Plot multiple systems together
file1= np.genfromtxt('64x64x64_dielectric_only.dat', delimiter = ' ')
file2= np.genfromtxt('64x64x64_dielectric+DFT.dat', delimiter = ' ')

plt.xlabel('Simulation temperature (K)')
plt.ylabel('Order parameter Q')
plt.plot(file1[:,0], abs(file1[:,1]), label='Scaled by $\epsilon_{macro}$ only')
plt.plot(file2[:,0], abs(file2[:,1]), ls='dashed', label='Scaled by defect formation energy')

plt.legend(loc='upper right', frameon=False)

plt.rcParams.update({'font.size': 16})

plt.xlim([150,1000])
plt.ylim([-0.04, 1.1])

plt.savefig("param_test.png")
plt.show()

# %% [markdown]
# #####
